# %%
#Ex1
# 2)numerical values
ice_cream_rating= 2
sleeping_rating= 7

# %%
# 3)string
first_name= "Marius"
last_name= "Tuyishime"
my_name= first_name + " " +last_name
print(my_name)
# Out:
# Marius Tuyishime

# %%
# 4) simple math operations
happiness_rating = (ice_cream_rating+sleeping_rating)/2

# %%
# 5) data type
print(type(ice_cream_rating))
print(type(first_name))
print(type(happiness_rating))
print(type(ice_cream_rating), type(first_name), type(happiness_rating))#combined
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>
# <class 'int'> <class 'str'> <class 'float'>

# %%
#yes the data make sense, 
#ice_cream_rating is a whole number, 
#happiness_rating, a floating number, it has decimals

#first_name data type is string, a sequence of character to form a text.
#a string data differ from others, which are numbers.

# %%
# 6 
first_name= "Dave"
last_name= "Whipp"
my_name= first_name+ " "+last_name
ice_cream_rating= 9
sleeping_rating=8
happiness_rating = (ice_cream_rating+sleeping_rating)/2


print(f"My name is {first_name} and I give eating ice cream a score of {ice_cream_rating} out of 10!")
print(f"I am {my_name} and my sleeping enjoyment is {sleeping_rating} / 10!")
print(f"Based on the factors above, my {happiness_rating} is 8.5 out of 10, or 85.0%!")
# Out:
# My name is Dave and I give eating ice cream a score of 9 out of 10!
# I am Dave Whipp and my sleeping enjoyment is 8 / 10!
# Based on the factors above, my 8.5 is 8.5 out of 10, or 85.0%!
